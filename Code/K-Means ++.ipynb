# %% [markdown]
# # K-Means Clustering
# ## Kyle Mikami

# %%
#import packages
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import glob
import sklearn
import pandasql
from pandasql import sqldf
import pickle
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### K-Means on Full Dataset

# %%
#Read in consolidated dataset
dataset = pd.read_csv("model_data2.csv")

# %%
dataset
# Out:
#    DISTRICT     MONTH  DAY_OF_WEEK       HOUR  Median Age  White Alone  \
# 0        A1  7.033408     4.034134  12.513945   32.986141     0.700316
# 1       A15  6.990224     3.826041  13.093500   34.900000     0.719667
# 2        A7  6.967226     3.962442  13.076501   32.866667     0.333833
# 3        B2  6.929485     3.913553  13.237799   30.097267     0.224368
# 4        B3  6.984170     3.949746  13.275074   37.066667     0.064500
# 5       C11  6.954368     3.935199  13.067816   33.133333     0.219833
# 6        C6  6.992721     3.969458  12.768413   32.153269     0.773607
# 7       D14  7.051409     3.976169  12.820425   28.934509     0.620495
# 8        D4  7.006984     3.955507  12.983868   30.529933     0.607478
# 9       E13  6.970813     3.879755  13.350468   34.100000     0.547167
# 10      E18  6.976090     3.879040  13.280177   38.966667     0.242500
# 11       E5  7.016397     3.901270  12.980163   40.959400     0.603411
#
#     Black / African American  Hispanic  Asian Alone  Other Races  ...  \
# 0                   0.029173  0.067944     0.175212     0.027454  ...
# 1                   0.063833  0.113500     0.080333     0.022833  ...
# 2                   0.026833  0.560500     0.041167     0.038167  ...
# 3                   0.389967  0.263748     0.079663     0.042449  ...
# 4                   0.723833  0.157167     0.019500     0.034833  ...
# 5                   0.430833  0.185167     0.101000     0.063000  ...
# 6                   0.052529  0.099930     0.052459     0.021453  ...
# 7                   0.046337  0.117377     0.174762     0.040817  ...
# 8                   0.073335  0.115707     0.167306     0.036406  ...
# 9                   0.119000  0.235500     0.058333     0.038500  ...
# 10                  0.457833  0.245333     0.018500     0.035667  ...
# 11                  0.151620  0.163743     0.050423     0.031090  ...
#
#     PROSTITUTION  RESTRAINING ORDER VIOLATIONS   ROBBERY  SEARCH WARRANTS  \
# 0       0.207862                      0.438652  3.255942         0.261958
# 1       0.000000                      0.354359  0.944578         0.253053
# 2       0.003705                      0.332539  1.238325         0.122911
# 3       0.100164                      0.805532  2.378504         0.702133
# 4       0.019438                      2.360219  4.850677         1.769451
# 5       0.089078                      0.536698  1.259134         0.223159
# 6       0.078554                      0.373794  1.591727         0.248840
# 7       0.109310                      0.197901  0.561975         0.194145
# 8       0.046381                      0.317460  1.705076         0.094601
# 9       0.004254                      0.306405  1.441597         0.318479
# 10      0.008896                      0.647392  1.097906         0.388570
# 11      0.002610                      0.160468  0.396425         0.186122
#
#      SERVICE     TOWED  VANDALISM  VERBAL DISPUTES  VIOLATIONS  \
# 0   0.079964  7.239948   7.067827         1.594640    1.818416
# 1   0.166541  4.608553   5.037885         2.570483    1.191922
# 2   0.137881  3.329743   4.537581         2.676015    1.435600
# 3   0.145011  3.417453   8.010383         9.089829    4.043674
# 4   0.396645  7.647783  19.247567        26.807097    8.484071
# 5   0.098609  2.583718   4.759928         4.975176    1.687260
# 6   0.139623  8.755471   7.343611         3.470135    1.363744
# 7   0.093932  5.144274   3.598129         1.760091    0.917704
# 8   0.079262  5.649420   5.130293         2.166338    1.369631
# 9   0.119816  5.239595   4.924821         3.472188    2.498392
# 10  0.172275  2.118176   5.568349         6.475936    2.259344
# 11  0.101885  1.241650   2.598989         2.142178    0.955549
#
#     WARRANT ARRESTS
# 0          6.784553
# 1          1.192759
# 2          1.296317
# 3          3.692102
# 4          4.878210
# 5          1.881792
# 6          3.342219
# 7          0.656967
# 8          2.904208
# 9          2.159070
# 10         1.135112
# 11         0.491906
#
# [12 rows x 69 columns]

# %%
#neighborhood_districts = pd.read_csv('Code/Data/Boston Neighborhood Districts.csv')

# %%
#Keep only relevant columns
data = dataset.drop(['DISTRICT', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)

# %%
data
# Out:
#        MONTH  DAY_OF_WEEK       HOUR  Median Age  Less than High School  \
# 0   7.033408     4.034134  12.513945   32.986141               0.094995
# 1   6.990224     3.826041  13.093500   34.900000               0.088483
# 2   6.967226     3.962442  13.076501   32.866667               0.297417
# 3   6.929485     3.913553  13.237799   30.097267               0.206361
# 4   6.984170     3.949746  13.275074   37.066667               0.173133
# 5   6.954368     3.935199  13.067816   33.133333               0.190950
# 6   6.992721     3.969458  12.768413   32.153269               0.079406
# 7   7.051409     3.976169  12.820425   28.934509               0.076610
# 8   7.006984     3.955507  12.983868   30.529933               0.074968
# 9   6.970813     3.879755  13.350468   34.100000               0.079483
# 10  6.976090     3.879040  13.280177   38.966667               0.128333
# 11  7.016397     3.901270  12.980163   40.959400               0.082936
#
#     Bachelor's Degree or more  Poverty rate  AIRCRAFT     ARSON    ASSAULT  \
# 0                    0.736119      0.153507  0.006881  0.052394  18.347000
# 1                    0.649333      0.171833  0.000000  0.035865   5.606626
# 2                    0.251333      0.185000  0.220112  0.018161   5.467322
# 3                    0.319703      0.348782  0.008671  0.074677  13.924128
# 4                    0.183667      0.203000  0.000000  0.111243  29.772719
# 5                    0.271667      0.227667  0.000000  0.015923   6.339770
# 6                    0.642607      0.145167  0.000000  0.028997  10.160311
# 7                    0.673646      0.225806  0.000000  0.018281   4.221752
# 8                    0.729393      0.264864  0.004036  0.033832   9.089148
# 9                    0.645500      0.150833  0.000000  0.025313   7.309472
# 10                   0.281000      0.120333  0.004614  0.014591   6.979735
# 11                   0.501613      0.089306  0.000000  0.026731   3.010925
#
#     ...  PROSTITUTION  RESTRAINING ORDER VIOLATIONS   ROBBERY  \
# 0   ...      0.207862                      0.438652  3.255942
# 1   ...      0.000000                      0.354359  0.944578
# 2   ...      0.003705                      0.332539  1.238325
# 3   ...      0.100164                      0.805532  2.378504
# 4   ...      0.019438                      2.360219  4.850677
# 5   ...      0.089078                      0.536698  1.259134
# 6   ...      0.078554                      0.373794  1.591727
# 7   ...      0.109310                      0.197901  0.561975
# 8   ...      0.046381                      0.317460  1.705076
# 9   ...      0.004254                      0.306405  1.441597
# 10  ...      0.008896                      0.647392  1.097906
# 11  ...      0.002610                      0.160468  0.396425
#
#     SEARCH WARRANTS   SERVICE     TOWED  VANDALISM  VERBAL DISPUTES  \
# 0          0.261958  0.079964  7.239948   7.067827         1.594640
# 1          0.253053  0.166541  4.608553   5.037885         2.570483
# 2          0.122911  0.137881  3.329743   4.537581         2.676015
# 3          0.702133  0.145011  3.417453   8.010383         9.089829
# 4          1.769451  0.396645  7.647783  19.247567        26.807097
# 5          0.223159  0.098609  2.583718   4.759928         4.975176
# 6          0.248840  0.139623  8.755471   7.343611         3.470135
# 7          0.194145  0.093932  5.144274   3.598129         1.760091
# 8          0.094601  0.079262  5.649420   5.130293         2.166338
# 9          0.318479  0.119816  5.239595   4.924821         3.472188
# 10         0.388570  0.172275  2.118176   5.568349         6.475936
# 11         0.186122  0.101885  1.241650   2.598989         2.142178
#
#     VIOLATIONS  WARRANT ARRESTS
# 0     1.818416         6.784553
# 1     1.191922         1.192759
# 2     1.435600         1.296317
# 3     4.043674         3.692102
# 4     8.484071         4.878210
# 5     1.687260         1.881792
# 6     1.363744         3.342219
# 7     0.917704         0.656967
# 8     1.369631         2.904208
# 9     2.498392         2.159070
# 10    2.259344         1.135112
# 11    0.955549         0.491906
#
# [12 rows x 61 columns]

# %%
#Pull distinct districts
districts = pd.DataFrame(dataset['DISTRICT'])

# %%
#Basic K-Means
kmeans = KMeans(n_clusters=5, init = "k-means++", n_init = 10)
y_kmeans = kmeans.fit_predict(data)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
clusters = pd.DataFrame(kmeans.labels_)
clusters
# Out:
#     0
# 0   2
# 1   4
# 2   4
# 3   0
# 4   1
# 5   4
# 6   3
# 7   4
# 8   3
# 9   0
# 10  0
# 11  4

# %%
districts.join(clusters)
# Out:
#    DISTRICT  0
# 0        A1  2
# 1       A15  4
# 2        A7  4
# 3        B2  0
# 4        B3  1
# 5       C11  4
# 6        C6  3
# 7       D14  4
# 8        D4  3
# 9       E13  0
# 10      E18  0
# 11       E5  4

# %%
#Hyperparameter tuning # of clusters using elbow method
distance_df = []
for num_clusters in range(1,12):
    km = KMeans(n_clusters=num_clusters, n_init = 10)
    km.fit(data)
    distance_df.append([num_clusters, km.inertia_])
distance_df = pd.DataFrame(distance_df, columns = ['num_clusters', 'distance'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
distance_df
# Out:
#     num_clusters     distance
# 0              1  5207.351446
# 1              2  2044.347976
# 2              3   985.916102
# 3              4   605.274211
# 4              5   457.957653
# 5              6   293.840555
# 6              7   200.916452
# 7              8   136.152955
# 8              9    62.086484
# 9             10    32.588448
# 10            11    12.337702

# %%
#Plot elbow curve
distance_df.set_index("num_clusters").plot()
plt.xlabel("# Clusters")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %% [markdown]
# We can see from the elbow curve that the ideal number of clusters is around 4 clusters.

# %%
#Run KMeans with 4 clusters
kmeans = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
y_kmeans = kmeans.fit_predict(data)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
clusters = pd.DataFrame(kmeans.labels_)
clusters
# Out:
#     0
# 0   2
# 1   3
# 2   3
# 3   0
# 4   1
# 5   3
# 6   0
# 7   3
# 8   2
# 9   0
# 10  0
# 11  3

# %%
districts.join(clusters)
# Out:
#    DISTRICT  0
# 0        A1  2
# 1       A15  3
# 2        A7  3
# 3        B2  0
# 4        B3  1
# 5       C11  3
# 6        C6  0
# 7       D14  3
# 8        D4  2
# 9       E13  0
# 10      E18  0
# 11       E5  3

# %%
#Summarize Clusters by Types of Crimes
#Join clusters to data
data['Cluster'] = clusters
#data

# %%
#Calculate averages by Cluster
summary = data.groupby('Cluster', as_index=False).mean()
summary
# Out:
#    Cluster     MONTH  DAY_OF_WEEK       HOUR  Median Age  \
# 0        0  6.967277     3.910452  13.159214   33.829301
# 1        1  6.984170     3.949746  13.275074   37.066667
# 2        2  7.020196     3.994821  12.748906   31.758037
# 3        3  6.995925     3.920224  13.007681   34.158782
#
#    Less than High School  Bachelor's Degree or more  Poverty rate  AIRCRAFT  \
# 0               0.123396                   0.472202      0.191279  0.003321
# 1               0.173133                   0.183667      0.203000  0.000000
# 2               0.084981                   0.732756      0.209185  0.005459
# 3               0.147279                   0.469518      0.179922  0.044022
#
#       ARSON  ...  PROSTITUTION  RESTRAINING ORDER VIOLATIONS   ROBBERY  \
# 0  0.035895  ...      0.047967                      0.533281  1.627433
# 1  0.111243  ...      0.019438                      2.360219  4.850677
# 2  0.043113  ...      0.127122                      0.378056  2.480509
# 3  0.022992  ...      0.040940                      0.316393  0.880088
#
#    SEARCH WARRANTS   SERVICE     TOWED  VANDALISM  VERBAL DISPUTES  \
# 0         0.414505  0.144181  4.882674   6.461791         5.627022
# 1         1.769451  0.396645  7.647783  19.247567        26.807097
# 2         0.178280  0.079613  6.444684   6.099060         1.880489
# 3         0.195878  0.119770  3.381588   4.106503         2.824788
#
#    VIOLATIONS  WARRANT ARRESTS
# 0    2.541289         2.582126
# 1    8.484071         4.878210
# 2    1.594024         4.844381
# 3    1.237607         1.103948
#
# [4 rows x 62 columns]

# %%
#Export summary to identify results
summary.to_csv('summary.csv', header=True, index=None)

# %% [markdown]
# ### K-Means on Each Year Separately

# %%
#Read in consolidated dataset
dataset_yearly = pd.read_csv("model_data_yearly2.csv")
dataset_yearly
# Out:
#    DISTRICT  YEAR     MONTH  DAY_OF_WEEK       HOUR  Median Age  White Alone  \
# 0        A1  2015  9.185894     3.997758  12.467150   32.661270     0.714909
# 1        A1  2016  6.546044     4.044214  12.437755   32.115835     0.712439
# 2        A1  2017  6.707128     4.110092  12.365662   32.266154     0.703850
# 3        A1  2018  6.546260     4.057284  12.550072   33.435971     0.691667
# 4        A1  2019  6.734545     4.036364  12.659144   33.560941     0.701228
# ..      ...   ...       ...          ...        ...         ...          ...
# 67       E5  2016  6.491969     3.895478  13.119842   40.122308     0.621829
# 68       E5  2017  6.678527     3.988474  13.039840   41.149645     0.610271
# 69       E5  2018  6.398635     3.883215  12.967897   41.146840     0.599071
# 70       E5  2019  6.617439     3.888828  13.349319   41.382734     0.596050
# 71       E5  2020  6.654453     3.903890  12.584837   41.353530     0.563676
#
#     Black / African American  Hispanic  Asian Alone  ...  PROSTITUTION  \
# 0                   0.027158  0.060292     0.172636  ...      0.169656
# 1                   0.026454  0.060894     0.176923  ...      0.309082
# 2                   0.028123  0.072998     0.172592  ...      0.724705
# 3                   0.029577  0.076794     0.173991  ...      0.000000
# 4                   0.031321  0.072256     0.167790  ...      0.023083
# ..                       ...       ...          ...  ...           ...
# 67                  0.149984  0.157372     0.045059  ...      0.000000
# 68                  0.150721  0.161674     0.050095  ...      0.000000
# 69                  0.154430  0.164810     0.052446  ...      0.015661
# 70                  0.155542  0.166194     0.051379  ...      0.000000
# 71                  0.153698  0.179538     0.057267  ...      0.000000
#
#     RESTRAINING ORDER VIOLATIONS   ROBBERY  SEARCH WARRANTS   SERVICE  \
# 0                       0.266602  2.593311         0.387785  0.048473
# 1                       0.689491  3.851641         0.261531  0.047551
# 2                       0.841593  4.161212         0.397419  0.116888
# 3                       0.689719  3.678499         0.252897  0.091962
# 4                       0.000000  3.000785         0.230830  0.092332
# ..                           ...       ...              ...       ...
# 67                      0.258102  0.467810         0.290365  0.129051
# 68                      0.174227  0.475165         0.285099  0.110872
# 69                      0.219257  0.438514         0.187935  0.046984
# 70                      0.000000  0.409146         0.157364  0.078682
# 71                      0.246115  0.246115         0.082038  0.196892
#
#        TOWED  VANDALISM  VERBAL DISPUTES  VIOLATIONS  WARRANT ARRESTS
# 0   4.726127   5.307804         0.557441    1.623849         5.307804
# 1   8.773181   8.464099         1.307656    1.688065        11.222064
# 2   9.351038   7.457453         2.010473    1.098747        12.647279
# 3   8.345595   7.816811         1.517381    1.471400         7.586905
# 4   6.855639   6.486312         2.585292    2.262130         3.323946
# ..       ...        ...              ...         ...              ...
# 67  1.064671   3.823136         2.435837    1.177590         0.854963
# 68  1.251267   2.993538         2.787633    0.807780         0.807780
# 69  2.239554   2.537117         2.959970    0.610787         0.673432
# 70  1.274647   2.218830         2.753867    0.834028         0.094418
# 71  1.050093   2.165816         1.427470    1.017277         0.000000
#
# [72 rows x 70 columns]

# %%
#Separate into annual datasets
d2015 = dataset_yearly[dataset_yearly['YEAR'] == 2015]
d2016 = dataset_yearly[dataset_yearly['YEAR'] == 2016]
d2017 = dataset_yearly[dataset_yearly['YEAR'] == 2017]
d2018 = dataset_yearly[dataset_yearly['YEAR'] == 2018]
d2019 = dataset_yearly[dataset_yearly['YEAR'] == 2019]
d2020 = dataset_yearly[dataset_yearly['YEAR'] == 2020]

# %%
#d2020

# %%
#Keep only relevant columns in each dataset
d2015 = d2015.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)
d2016 = d2016.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)
d2017 = d2017.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)
d2018 = d2018.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)
d2019 = d2019.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)
d2020 = d2020.drop(['DISTRICT', 'YEAR', 'White Alone', 'Black / African American', 'Hispanic', 'Asian Alone', 'Other Races', 'High School Graduate', 'Some College'], axis = 1)

# %%
#Run KMeans on each Year
k15 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
k16 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
k17 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
k18 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
k19 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)
k20 = KMeans(n_clusters = 4, init = "k-means++", n_init = 10)

y_k15 = k15.fit_predict(d2015)
y_k16 = k16.fit_predict(d2016)
y_k17 = k17.fit_predict(d2017)
y_k18 = k18.fit_predict(d2018)
y_k19 = k19.fit_predict(d2019)
y_k20 = k20.fit_predict(d2020)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#Clusters for each year
clusters15 = pd.DataFrame(k15.labels_)
clusters16 = pd.DataFrame(k16.labels_)
clusters17 = pd.DataFrame(k17.labels_)
clusters18 = pd.DataFrame(k18.labels_)
clusters19 = pd.DataFrame(k19.labels_)
clusters20 = pd.DataFrame(k20.labels_)

# %%
#Consolidate all years into one table
yearly_clusters = districts
yearly_clusters['Neighborhoods'] = ['Downtown areas', 'Charlestown', 'East Boston', 'Roxbury/Longwood/Mission Hill', 
                                    'Mattapan', 'Dorchester', 'South Boston', 'Allston/Brighton', 
                                    'South End/Back Bay/Fenway', 'Jamaica Plain', 'Hyde Park', 'West Roxbury/Roslindale']

yearly_clusters = yearly_clusters.join(clusters) #get original clusters
yearly_clusters.columns = ['DISTRICT', 'Neighborhoods','Overall Cluster']

yearly_clusters['2015'] = clusters15
yearly_clusters['2016'] = clusters16
yearly_clusters['2017'] = clusters17
yearly_clusters['2018'] = clusters18
yearly_clusters['2019'] = clusters19
yearly_clusters['2020'] = clusters20

# %%
yearly_clusters
# Out:
#    DISTRICT                  Neighborhoods  Overall Cluster  2015  2016  2017  \
# 0        A1                 Downtown areas                2     2     3     1
# 1       A15                    Charlestown                3     3     1     3
# 2        A7                    East Boston                3     3     1     3
# 3        B2  Roxbury/Longwood/Mission Hill                0     1     2     0
# 4        B3                       Mattapan                1     0     0     2
# 5       C11                     Dorchester                3     3     1     3
# 6        C6                   South Boston                0     1     2     0
# 7       D14               Allston/Brighton                3     3     1     3
# 8        D4      South End/Back Bay/Fenway                2     1     3     1
# 9       E13                  Jamaica Plain                0     3     2     0
# 10      E18                      Hyde Park                0     3     2     0
# 11       E5        West Roxbury/Roslindale                3     3     1     3
#
#     2018  2019  2020
# 0      3     2     2
# 1      1     0     0
# 2      1     0     0
# 3      0     3     3
# 4      2     1     1
# 5      1     0     0
# 6      0     3     2
# 7      1     0     0
# 8      3     3     2
# 9      0     3     0
# 10     0     3     3
# 11     1     0     0

# %% [markdown]
# Takeaways:
# - Mattapan is always its own cluster in every year and seems to have a unique crime profile.
# - The downtown areas typically comprise their own cluster across the years, but are occasionally grouped with the South End/Back Bay/Fenway area, which makes sense.  In 2020, South Boston was clustered with those areas instead of other non-downtown areas, suggesting that Southie is becoming more like downtown in terms of crime as even more construction occurs there, etc.
# - Generally, the Roxbury/Longwood/Mission Hill neighborhood is clustered with areas like Hyde Park, JP, and Southie.
# - As mentioned in the slides, many of the neighborhoods around the perimeter of the city of Boston (Charlestown, East Boston, Dorchester, Allston/Brighton, and West Roxbury/Roslindale) are typically clustered together.  In some years, Jamaica Plain and Hyde Park are also clustered with these neighborhoods.  This cluster comprises most of the land area of Boston.

# %%
#Silhouette scores overall and by year
print("Overall: ", silhouette_score(data, kmeans.labels_))
print("2015: ", silhouette_score(d2015, k15.labels_))
print("2016: ", silhouette_score(d2016, k16.labels_))
print("2017: ", silhouette_score(d2017, k17.labels_))
print("2018: ", silhouette_score(d2018, k18.labels_))
print("2019: ", silhouette_score(d2019, k19.labels_))
print("2020: ", silhouette_score(d2020, k20.labels_))
# Out:
# Overall:  0.2923654158552943
# 2015:  0.34360075520943784
# 2016:  0.2637844600236229
# 2017:  0.2531092504973347
# 2018:  0.27452847596946783
# 2019:  0.2595272263301555
# 2020:  0.3318716709427133

# %%
#Add silhouette scores to dataframe
silhouette_scores = []
silhouette_scores.append(round(silhouette_score(data, kmeans.labels_),4))
silhouette_scores.append(round(silhouette_score(d2015, k15.labels_),4))
silhouette_scores.append(round(silhouette_score(d2016, k16.labels_),4))
silhouette_scores.append(round(silhouette_score(d2017, k17.labels_),4))
silhouette_scores.append(round(silhouette_score(d2018, k18.labels_),4))
silhouette_scores.append(round(silhouette_score(d2019, k19.labels_),4))
silhouette_scores.append(round(silhouette_score(d2020, k20.labels_),4))

# %%
sil = pd.DataFrame()
sil['Year'] = ['Overall', '2015', '2016', '2017', '2018', '2019', '2020']
sil['K-Means Silhouette Score'] = silhouette_scores

# %%
#Dataframe with silhouette score by year
sil
# Out:
#       Year  K-Means Silhouette Score
# 0  Overall                    0.2924
# 1     2015                    0.3436
# 2     2016                    0.2638
# 3     2017                    0.2531
# 4     2018                    0.2745
# 5     2019                    0.2595
# 6     2020                    0.3319
